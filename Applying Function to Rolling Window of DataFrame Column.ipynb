# %% [markdown]
# ## Goals
# Calculate the **Relative Strength Index** (or RSI), which is a rolling indicator that looks at N periods of return data
#
# - RSI = 100 - 100 / (1 + RS)
# - RS = Average Gain / Average Loss
# - Average Gain = SUM( ABS( Return )) / N, where Return > 0
# - Average Loss = SUM( ABS( Return )) / N, where Return < 0
#
# Similarly, there is a need to calculate the **N Day Forward Return**, which will calculate the return from the next period's **Open** to the Nth period's **Adj Close**.
#
# Using the `history_BWLD.head(15)` as an example, the **10 Day Forward Return** from **2011-11-21** will be:
#
# ```
# Quantity Adj Close at 2011-12-06 minus Open at 2011-11-22, divided by Open at 2011-11-22
# (62.810001 - 61.619999) / 61.619999 = 0.019311944 = 1.93%
# ```

# %%
# Import Pandas
import pandas as pd
import numpy as np
history_BWLD = pd.read_csv('source-data/BWLD.csv').sort_values('Date').reset_index().drop('index', 1)
history_BWLD['Return'] = history_BWLD['Adj Close'] - history_BWLD['Open']
history_BWLD.head(15)
# Out:
#           Date       Open       High        Low      Close  Volume  Adj Close  \
# 0   2011-11-21  62.549999  62.910000  61.349998  61.770000  376000  61.770000
# 1   2011-11-22  61.619999  62.580002  61.400002  62.099998  296700  62.099998
# 2   2011-11-23  61.549999  62.840000  60.849998  61.279999  437600  61.279999
# 3   2011-11-25  60.970001  61.459999  59.830002  59.860001  143900  59.860001
# 4   2011-11-28  61.830002  64.970001  61.509998  64.790001  772900  64.790001
# 5   2011-11-29  64.959999  65.620003  63.910000  63.980000  488500  63.980000
# 6   2011-11-30  65.870003  65.919998  63.570000  64.480003  729600  64.480003
# 7   2011-12-01  64.650002  65.370003  63.560001  64.349998  334100  64.349998
# 8   2011-12-02  64.279999  65.750000  63.910000  64.190002  277800  64.190002
# 9   2011-12-05  64.400002  65.000000  63.189999  63.389999  349200  63.389999
# 10  2011-12-06  63.090000  63.299999  61.869999  62.810001  323400  62.810001
# 11  2011-12-07  62.090000  63.340000  61.970001  63.000000  307400  63.000000
# 12  2011-12-08  62.680000  63.680000  62.000000  62.040001  385000  62.040001
# 13  2011-12-09  62.099998  62.709999  61.779999  62.419998  241000  62.419998
# 14  2011-12-12  61.549999  62.599998  61.439999  62.500000  276500  62.500000
#
#       Return
# 0  -0.779999
# 1   0.479999
# 2  -0.270000
# 3  -1.110000
# 4   2.959999
# 5  -0.979999
# 6  -1.390000
# 7  -0.300004
# 8  -0.089997
# 9  -1.010003
# 10 -0.279999
# 11  0.910000
# 12 -0.639999
# 13  0.320000
# 14  0.950001

# %%
def calculate_rolling_up_sum(series):
    print()
    returns_positive = 0
    returns_negative = 0
    for x in series:
        print(x)
        if x > 0:
            returns_positive += x
        elif x < 0:
            returns_negative += abs(x)
    print(str(returns_positive) + ' ' + str(returns_negative))

# This produces correct results for rolling window, but throws an error
history_BWLD['Returns Pos Neg'] = history_BWLD['Return'].rolling(window=10).apply(calculate_rolling_up_sum)
# Out:
# -0.779999
# 0.479999
# -0.27
# -1.11
# 2.959999
# -0.979999
# -1.39
# -0.300004
# -0.089997
# -1.010003
# 3.439998 5.930002
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-1644360bd1c8> in <module>()
#      12
#      13 # This produces correct results for rolling window, but throws an error
# ---> 14 history_BWLD['Returns Pos Neg'] = history_BWLD['Return'].rolling(window=10).apply(calculate_rolling_up_sum)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/window.py in apply(self, func, args, kwargs)
#    1082     @Appender(_shared_docs['apply'])
#    1083     def apply(self, func, args=(), kwargs={}):
# -> 1084         return super(Rolling, self).apply(func, args=args, kwargs=kwargs)
#    1085
#    1086     @Substitution(name='rolling')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/window.py in apply(self, func, args, kwargs)
#     803
#     804         return self._apply(f, func, args=args, kwargs=kwargs,
# --> 805                            center=False)
#     806
#     807     def sum(self, *args, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/window.py in _apply(self, func, name, window, center, check_minp, how, **kwargs)
#     738                     result = np.apply_along_axis(calc, self.axis, values)
#     739                 else:
# --> 740                     result = calc(values)
#     741
#     742             if center:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/window.py in calc(x)
#     732
#     733                 def calc(x):
# --> 734                     return func(x, window, min_periods=self.min_periods)
#     735
#     736             with np.errstate(all='ignore'):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/window.py in f(arg, window, min_periods)
#     800             return _window.roll_generic(arg, window, minp, indexi,
#     801                                         offset, func, args,
# --> 802                                         kwargs)
#     803
#     804         return self._apply(f, func, args=args, kwargs=kwargs,
#
# /pandas/window.pyx in pandas._window.roll_generic (pandas/window.c:35126)()
#
# TypeError: a float is required
